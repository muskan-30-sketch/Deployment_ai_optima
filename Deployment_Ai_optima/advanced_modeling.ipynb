# %% [markdown]
# # Milestone 5: Advanced Model Development (Corrected)\n
# \n
# Clean wrapper notebook that runs `Milestone_5_ML_Pricing_corrected.py` and prints:\n
# - Demand prediction metrics (MAE, RMSE, R²)\n
# - Revenue comparison and lift vs Static Pricing\n
# \n
# All artifacts are saved to `data/daily_ingest/`.

# %%
import runpy
from pathlib import Path

import pandas as pd

# Run corrected training + backtesting\n
script_path = Path('data/Milestone_5_ML_Pricing_corrected.py')
runpy.run_path(str(script_path))

out_dir = script_path.parent
metrics_df = pd.read_csv(out_dir / 'milestone5_model_metrics.csv')
revenue_df = pd.read_csv(out_dir / 'milestone5_revenue_comparison.csv')

print('Model metrics (demand prediction):')
print(metrics_df.to_string(index=False))

print('\nRevenue comparison (Static vs Rule-Based vs ML-Based):')
print(revenue_df.to_string(index=False))

print('\nRevenue lift formula used:')
print('(New Revenue − Original Revenue) / Original Revenue × 100')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       6 # Run corrected training + backtesting\n
#       7 script_path = Path('data/Milestone_5_ML_Pricing_corrected.py')
# ----> 8 runpy.run_path(str(script_path))
#      10 out_dir = script_path.parent
#      11 metrics_df = pd.read_csv(out_dir / 'milestone5_model_metrics.csv')
#
# File <frozen runpy>:286, in run_path(path_name, init_globals, run_name)
#
# File <frozen runpy>:254, in _get_code_from_file(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Muskan\\OneDrive\\Desktop\\AI_Price_optima\\data\\daily_ingest\\data\\Milestone_5_ML_Pricing_corrected.py'
